# %% [markdown]
# ### 필수 라이브러리 설치 및 로드하기(+ API KEY 설정)

# %%
# !pip install -q langchain openai langchain-openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.1/289.1 kB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 5.2 MB/s eta 0:00:00

# %%
import os
# https://platform.openai.com/docs/guides/gpt/completions-api
os.environ["OPENAI_API_KEY"] = 'apikey'

# %% [markdown]
# ### (1) API를 통해 GPT-3, ChatGPT와 대화해보기

# %%
from langchain_openai import OpenAI
llm = OpenAI()
result = llm.invoke('왜 파이썬이 가장 인기있는 프로그래밍 언어야?')
print(result)
# Out:
# 1. 간결하고 쉬운 문법: 파이썬은 다른 언어에 비해 문법이 간결하고 쉬워서 배우기 쉽습니다. 또한 코드의 가독성이 좋아서 유지보수가 용이합니다.
#
# 2. 다양한 용도로 활용 가능: 파이썬은 웹 개발, 데이터 분석, 인공지능 등 다양한 분야에서 유연하게 사용할 수 있기 때문에 여러 분야의 개발자들에게 인기가 있습니다.
#
# 3. 강력한 라이브러리: 파이썬은 다양한 라이브러리를 제공해주기 때문에 개발자들이 직접 구현할 필요 없이 빠르게 개발할 수 있습니다.
#
# 4. 큰 커뮤니티: 파이썬은 전 세계적

# %%
from langchain_openai import OpenAI
llm = OpenAI()
llm = OpenAI(model_name = 'gpt-3.5-turbo-instruct', max_tokens = -1)
result = llm.invoke('왜 파이썬이 가장 인기있는 프로그래밍 언어야?')
print(result)
# Out:
# 1. 다양한 용도에 적합하다
# 파이썬은 데이터 분석, 인공지능, 웹 개발, 게임 개발 등 다양한 분야에서 사용되며 어떤 분야에서도 유용하게 활용될 수 있다.
#
# 2. 배우기 쉽다
# 다른 프로그래밍 언어와 비교했을 때 문법이 간결하고 읽기 쉽기 때문에 초보자들도 쉽게 배울 수 있다. 또한 인터프리터 언어로 작성된 코드는 바로 실행되기 때문에 학습 과정에서 바로 결과를 확인할 수 있다.
#
# 3. 생산성이 높다
# 파이썬은 간결한 문법과 다양한 라이브러리를 제공하며, 코드를 빠르게 작성할 수 있도록 도와준다. 이로 인해 개발자들은 더 많은 기능을 짧은 시간에 구현할 수 있어 생산성이 높아진다.
#
# 4. 커뮤니티가 활발하다
# 파이썬은 전 세계적으로 많은 개발자들이 사용하며, 이를 지원하는 다양한 커뮤니티가 존재한다. 이러한 커뮤니티는 다양한 문제에 대한 해결책을 제공하고 새로운 기능을 공유함으로써 파이썬의 발전을 이끌어낸다.
#
# 5. 크로스 플랫폼 지원
# 파이썬은 다양한 운영체제에서 동작하기 때문에 윈도우, 맥, 리눅스 등 어떤 운영체제에서도 사용할 수 있다.
#
# 6. 라이브러리가 풍부하다
# 파이썬은 다양한 분야에서 사용할 수 있는 라이브러리가 많이 제공된다. 이러한 라이브러리들은 개발 시간을 단축해주고, 코드의 재사용성을 높여준다.
#
# 7. 인공지능과 빅데이터 분야에서 강력하다
# 파이썬은 인공지능과 빅데이터 분야에서 많이 사용되며, 이 분야에서 파이썬을 활용하는 라이브러리는 지속적으로 발전하고 있다.
#
# 8. 공개 소스 코드
# 파이썬은 공개 소스 코드로 개발되어 있기 때문에 누구나 코드를 수정하고 개선할 수 있다. 이를 통해 더 나은 파이썬 프로그래밍 환경을 만들어나갈 수 있다.
#
# 9. 취업 기회가 많다
# 파이썬은 다양한 분야에서 사용되기 때문에 파이썬을 잘 다룰 수 있는 개발자는 취업 기회가 많다. 또한 인공지능과 빅데이터 분야의 성장에 따라 파이썬 개발자의 수요도 더욱 증가할 것으로 예상된다.
#
# 10. 미래 지향적인 언어이다
# 파이썬은 지속적으로 발전하고 있는 언어로, 미래에도 계속해서 발전할 것으로 예상된다. 따라서 파이썬을 배우는 것은 미래를 위한 준비이기도 하다.

# %% [markdown]
# ChatGPT API는 기본 OpenAI LLM들과 다른 Input 형식을 갖고 있습니다.
#
# ChatGPT는 대화에 특화된 LLM인만큼, 아래와 같은 2가지 독특한 매개변수를 지닙니다.
#
# ---
#
# (1) SystemMessage: ChatGPT에게 역할을 부여하여, 대화의 맥락을 설정하는 메세지
#
# (2) HumanMessage: 사용자가 ChatGPT에게 대화 또는 요청을 위해 보내는 메세지
#
# 위 두가지 형식을 적절히 활용하면, LLM을 더욱 효과적으로 사용할 수 있습니다.

# %%
from langchain_openai import ChatOpenAI
# 'ChatOpenAI'
chatgpt = ChatOpenAI(model_name="gpt-3.5-turbo", max_tokens = 512)
answer = chatgpt.invoke("왜 파이썬이 가장 인기있는 프로그래밍 언어야?")
print(answer.content)
# Out:
# 파이썬이 가장 인기 있는 프로그래밍 언어가 되었던 이유는 여러 가지가 있습니다.
#
# 첫째, 파이썬은 배우기 쉽고 읽기 쉬운 문법을 가지고 있어 초보자들도 쉽게 프로그래밍을 배울 수 있습니다. 또한 다양한 라이브러리와 프레임워크가 존재하여 다양한 분야에 적용할 수 있습니다.
#
# 둘째, 파이썬은 다양한 운영 체제에서 사용할 수 있으며, 크로스 플랫폼 언어로 사용될 수 있기 때문에 많은 사람들이 사용하고 있습니다.
#
# 셋째, 데이터 과학 및 인공 지능 분야에서도 널리 사용되는 언어이기 때문에 이 분야에 관심이 있는 사람들에게도 인기가 많습니다.
#
# 마지막으로, 파이썬은 커뮤니티가 활발하고 다양한 온라인 자료와 도움을 받을 수 있는 자료가 많기 때문에 사용자들이 쉽게 정보를 얻을 수 있습니다.
#
# 이러한 이유들로 인해 파이썬은 가장 인기 있는 프로그래밍 언어 중 하나가 되었습니다.

# %%
answer
# Out:
# AIMessage(content='파이썬이 가장 인기 있는 프로그래밍 언어가 되었던 이유는 여러 가지가 있습니다. \n\n첫째, 파이썬은 배우기 쉽고 읽기 쉬운 문법을 가지고 있어 초보자들도 쉽게 프로그래밍을 배울 수 있습니다. 또한 다양한 라이브러리와 프레임워크가 존재하여 다양한 분야에 적용할 수 있습니다.\n\n둘째, 파이썬은 다양한 운영 체제에서 사용할 수 있으며, 크로스 플랫폼 언어로 사용될 수 있기 때문에 많은 사람들이 사용하고 있습니다.\n\n셋째, 데이터 과학 및 인공 지능 분야에서도 널리 사용되는 언어이기 때문에 이 분야에 관심이 있는 사람들에게도 인기가 많습니다.\n\n마지막으로, 파이썬은 커뮤니티가 활발하고 다양한 온라인 자료와 도움을 받을 수 있는 자료가 많기 때문에 사용자들이 쉽게 정보를 얻을 수 있습니다.\n\n이러한 이유들로 인해 파이썬은 가장 인기 있는 프로그래밍 언어 중 하나가 되었습니다.', response_metadata={'token_usage': {'completion_tokens': 378, 'prompt_tokens': 32, 'total_tokens': 410}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': 'fp_c2295e73ad', 'finish_reason': 'stop', 'logprobs': None}, id='run-0c559c8d-5231-4f55-9cd9-bbdac07968c5-0')

# %% [markdown]
# ### (2) 매개변수 조절해보기

# %% [markdown]
# #### Temperature의 의미 이해해보기
# - 일관성
# - 0 = 일반적
# - 1 = 창의적

# %%
chatgpt_temp0_1 = ChatOpenAI(model_name="gpt-3.5-turbo", temperature = 0, max_tokens = 512)
chatgpt_temp0_2 = ChatOpenAI(model_name="gpt-3.5-turbo", temperature = 0, max_tokens = 512)
chatgpt_temp1_1 = ChatOpenAI(model_name="gpt-3.5-turbo", temperature = 1, max_tokens = 512)
chatgpt_temp1_2 = ChatOpenAI(model_name="gpt-3.5-turbo", temperature = 1, max_tokens = 512)

model_list = [chatgpt_temp0_1, chatgpt_temp0_2, chatgpt_temp1_1, chatgpt_temp1_2]

for i in model_list:
    answer = i.invoke("Why python is so popular?", max_tokens = 128)
    print("-"*100)
    print(">>>",answer.content)

# a bit different result.
# Out:
# ----------------------------------------------------------------------------------------------------
# >>> Python is popular for several reasons:
#
# 1. Easy to learn and use: Python has a simple and readable syntax that makes it easy for beginners to learn and use. This makes it a popular choice for those new to programming.
#
# 2. Versatile: Python is a versatile language that can be used for a wide range of applications, including web development, data analysis, artificial intelligence, machine learning, and more.
#
# 3. Large standard library: Python comes with a large standard library that provides ready-to-use modules and packages for common tasks, making it easy for developers to quickly build applications without having to write everything from scratch.
#
# 4. Community support
# ----------------------------------------------------------------------------------------------------
# >>> Python is popular for several reasons:
#
# 1. Easy to learn and use: Python has a simple and readable syntax that makes it easy for beginners to learn and use. This makes it a popular choice for those new to programming.
#
# 2. Versatile: Python is a versatile language that can be used for a wide range of applications, including web development, data analysis, artificial intelligence, machine learning, and more.
#
# 3. Large community and support: Python has a large and active community of developers who contribute to its development and provide support through forums, tutorials, and documentation.
#
# 4. Extensive libraries and frameworks: Python has a rich ecosystem of
# ----------------------------------------------------------------------------------------------------
# >>> There are several reasons why Python has become so popular:
#
# 1. Easy to learn: Python has a simple and easy-to-read syntax, making it accessible to beginners and experienced programmers alike.
#
# 2. Versatile and flexible: Python can be used for a wide range of applications, from web development to data analysis, machine learning, and artificial intelligence.
#
# 3. Strong community support: Python has a large and active community of developers who contribute to its development and provide support to others through forums, online tutorials, and documentation.
#
# 4. Extensive libraries and frameworks: Python has a rich ecosystem of libraries and frameworks that make it easy to build complex applications
# ----------------------------------------------------------------------------------------------------
# >>> 1. Easy to learn and use: Python has a simple syntax that is easy to understand and use, making it accessible for beginners and experienced programmers alike.
#
# 2. Versatile: Python is a versatile language that can be used for a wide range of applications, including web development, data analysis, artificial intelligence, machine learning, and more.
#
# 3. Large standard library: Python has a large standard library that provides built-in functions and modules for common programming tasks, reducing the need for developers to write code from scratch.
#
# 4. Community support: Python has a large and active community of developers who contribute to its development and provide support through online forums

# %% [markdown]
# ####ChatGPT처럼 실시간 응답 출력이 가능하도록 해보기

# %%
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
# typing 처럼
chatgpt = ChatOpenAI(model_name="gpt-3.5-turbo", streaming=True, callbacks=[StreamingStdOutCallbackHandler()], temperature = 1)
answer = chatgpt.predict("Why python is so popular?")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `predict` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# There are several reasons why Python has become so popular:
#
# 1. Easy to Learn and Use: Python has a simple and easy-to-understand syntax, making it an ideal language for beginners to learn. It is also readable and concise, helping developers write cleaner and more maintainable code.
#
# 2. Versatility: Python is a versatile language that can be used for a wide range of applications, including web development, data analysis, machine learning, artificial intelligence, and more. Its extensive standard library and third-party packages make it easy to build complex applications quickly.
#
# 3. Community Support: Python has a large and active community of developers who contribute to the language's growth and development. This community provides support, resources, and tools for developers to use, making it easier to learn and use Python effectively.
#
# 4. Data Science and Machine Learning: Python has become the language of choice for data science and machine learning due to its powerful libraries such as NumPy, Pandas, and scikit-learn. These libraries make it easy to work with data and build machine learning models, making Python an essential tool for anyone working in these fields.
#
# 5. Job Opportunities: The demand for Python developers has been steadily increasing in recent years, with many companies using Python for their projects. Learning Python can open up a wide range of job opportunities in various industries, making it a valuable skill to have in today's job market.
#
# Overall, Python's simplicity, versatility, community support, and job opportunities have all contributed to its popularity as a programming language.

# %%
for chunk in chatgpt.stream(
    "Why python is so popular?"
):
    print(chunk.content, end="", flush=True)
# Out:
# Python is so popular for several reasons:
#
# 1. Ease of learning: Python is known for its simple and readable syntax, making it easy for beginners to pick up and understand.
#
# 2. Versatility: Python can be used for a wide range of applications, including web development, data analysis, artificial intelligence, and more. It is a general-purpose language that can be used for almost any type of project.
#
# 3. Large community: Python has a large and active community of developers who contribute to its libraries and frameworks, making it easy to find support and resources.
#
# 4. Extensive libraries and frameworks: Python has a rich ecosystem of libraries and frameworks that make it easy to implement complex functionalities without having to write code from scratch.
#
# 5. Portability: Python is a cross-platform language, meaning it can run on various operating systems without any modifications, making it a versatile choice for developers.
#
# 6. Job opportunities: Python is one of the most in-demand programming languages in the job market, with many companies looking for developers with Python skills.
#
# Overall, Python's simplicity, versatility, and strong community support have contributed to its widespread popularity and adoption in the programming world.

# %% [markdown]
# #### ChatGPT에게 역할 부여하기

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import AIMessage, HumanMessage, SystemMessage

chatgpt = ChatOpenAI(model_name="gpt-3.5-turbo", temperature = 1)

messages = [
    SystemMessage(
        content="You are a 20 years senior software developer. Answer the question cheekily."
    ),
    HumanMessage(
        content="Tell me pros about python."
    ),
]
response_langchain = chatgpt.invoke(messages)
response_langchain.content
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# "Ah, Python, where do I start? Well, it's easy to read and write, great for beginners and experts alike. It has a vast library of packages to make your life easier and let's not forget about the indentation - who needs curly braces anyway, right? Plus, who doesn't love a language named after a classic British comedy group?"

# %% [markdown]
# ### (3) LLM 응답 캐싱하여 같은 질문에 더 빠르게 응답받기

# %%
from langchain.globals import set_llm_cache
from langchain_openai import OpenAI

# To make the caching really obvious, lets use a slower model.
llm = OpenAI(model_name="gpt-3.5-turbo-instruct", n=2, best_of=2)

# %%
# %%time
from langchain.cache import InMemoryCache

set_llm_cache(InMemoryCache())

# The first time, it is not yet in cache, so it should take longer
llm.predict("Tell me a joke")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `predict` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# CPU times: user 363 ms, sys: 37.5 ms, total: 400 ms
# Wall time: 1.1 s
# '\n\nWhy did the tomato turn red?\n\nBecause it saw the salad dressing!'

# %%
# %%time
# The second time it is, so it goes faster
llm.predict("Tell me a joke")
# Out:
# CPU times: user 693 µs, sys: 0 ns, total: 693 µs
# Wall time: 702 µs
# '\n\nWhy did the tomato turn red?\n\nBecause it saw the salad dressing!'

# %% [markdown]
# ### (4) 실습해보기

# %%
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage

chat = ChatOpenAI(temperature = 1, streaming=True, callbacks=[StreamingStdOutCallbackHandler()])
answer = chat(
  [
    SystemMessage(content="""You are a study planner machine that sets up study plans. When a user inputs a study topic, you create a study plan for learning it."""),
    HumanMessage(content="I want to become an expert at LLM.")
  ]
)
# Out:
# Great choice! To become an expert at LLM (Master of Laws), you will need to dedicate time and effort to studying various legal concepts and developing advanced knowledge in the field. Here is a suggested study plan to help you achieve your goal:
#
# **Week 1-2: Introduction to LLM**
# - Day 1-2: Overview of the legal system and different branches of law
# - Day 3-4: Understanding the purpose and structure of an LLM program
# - Day 5-6: Researching top LLM programs and potential areas of specialization
# - Day 7: Review and set goals for the upcoming weeks
#
# **Week 3-6: Deep Dive into LLM Curriculum**
# - Day 1-2: Study core legal subjects such as contracts, constitutional law, and torts
# - Day 3-4: Explore elective courses based on your interests (e.g., international law, environmental law)
# - Day 5-6: Start reading key textbooks and academic articles in your chosen specialization
# - Day 7: Review and revise your study plan based on your progress
#
# **Week 7-10: Legal Writing and Research Skills**
# - Day 1-2: Master legal citation and writing style (e.g., Bluebook)
# - Day 3-4: Practice drafting legal memos, briefs, and research papers
# - Day 5-6: Develop effective legal research techniques using online databases and libraries
# - Day 7: Conduct a mock research project to test your skills
#
# **Week 11-14: Networking and Professional Development**
# - Day 1-2: Attend legal conferences, seminars, and networking events
# - Day 3-4: Connect with legal professionals and alumni in your chosen field
# - Day 5-6: Update your resume and LinkedIn profile with your LLM coursework and achievements
# - Day 7: Reflect on your progress and set future career goals
#
# Remember to dedicate regular study hours each day, stay organized, and seek help from professors or mentors when needed. Good luck on your journey to becoming an expert in LLM!

# %%
#ChatGPT의 대답은 AIMessage라는 딕셔너리 형태로 제공됩니다.
answer
# Out:
# AIMessage(content='Great choice! To become an expert at LLM (Master of Laws), you will need to dedicate time and effort to studying various legal concepts and developing advanced knowledge in the field. Here is a suggested study plan to help you achieve your goal:\n\n**Week 1-2: Introduction to LLM**\n- Day 1-2: Overview of the legal system and different branches of law\n- Day 3-4: Understanding the purpose and structure of an LLM program\n- Day 5-6: Researching top LLM programs and potential areas of specialization\n- Day 7: Review and set goals for the upcoming weeks\n\n**Week 3-6: Deep Dive into LLM Curriculum**\n- Day 1-2: Study core legal subjects such as contracts, constitutional law, and torts\n- Day 3-4: Explore elective courses based on your interests (e.g., international law, environmental law)\n- Day 5-6: Start reading key textbooks and academic articles in your chosen specialization\n- Day 7: Review and revise your study plan based on your progress\n\n**Week 7-10: Legal Writing and Research Skills**\n- Day 1-2: Master legal citation and writing style (e.g., Bluebook)\n- Day 3-4: Practice drafting legal memos, briefs, and research papers\n- Day 5-6: Develop effective legal research techniques using online databases and libraries\n- Day 7: Conduct a mock research project to test your skills\n\n**Week 11-14: Networking and Professional Development**\n- Day 1-2: Attend legal conferences, seminars, and networking events\n- Day 3-4: Connect with legal professionals and alumni in your chosen field\n- Day 5-6: Update your resume and LinkedIn profile with your LLM coursework and achievements\n- Day 7: Reflect on your progress and set future career goals\n\nRemember to dedicate regular study hours each day, stay organized, and seek help from professors or mentors when needed. Good luck on your journey to becoming an expert in LLM!', response_metadata={'finish_reason': 'stop'}, id='run-13a46e03-1754-4f97-8c64-dd234f8b6b79-0')

# %%
#content를 key값으로 호출하여 를 통해 text만 출력할 수 있습니다.
print(answer.content)
# Out:
# Great choice! To become an expert at LLM (Master of Laws), you will need to dedicate time and effort to studying various legal concepts and developing advanced knowledge in the field. Here is a suggested study plan to help you achieve your goal:
#
# **Week 1-2: Introduction to LLM**
# - Day 1-2: Overview of the legal system and different branches of law
# - Day 3-4: Understanding the purpose and structure of an LLM program
# - Day 5-6: Researching top LLM programs and potential areas of specialization
# - Day 7: Review and set goals for the upcoming weeks
#
# **Week 3-6: Deep Dive into LLM Curriculum**
# - Day 1-2: Study core legal subjects such as contracts, constitutional law, and torts
# - Day 3-4: Explore elective courses based on your interests (e.g., international law, environmental law)
# - Day 5-6: Start reading key textbooks and academic articles in your chosen specialization
# - Day 7: Review and revise your study plan based on your progress
#
# **Week 7-10: Legal Writing and Research Skills**
# - Day 1-2: Master legal citation and writing style (e.g., Bluebook)
# - Day 3-4: Practice drafting legal memos, briefs, and research papers
# - Day 5-6: Develop effective legal research techniques using online databases and libraries
# - Day 7: Conduct a mock research project to test your skills
#
# **Week 11-14: Networking and Professional Development**
# - Day 1-2: Attend legal conferences, seminars, and networking events
# - Day 3-4: Connect with legal professionals and alumni in your chosen field
# - Day 5-6: Update your resume and LinkedIn profile with your LLM coursework and achievements
# - Day 7: Reflect on your progress and set future career goals
#
# Remember to dedicate regular study hours each day, stay organized, and seek help from professors or mentors when needed. Good luck on your journey to becoming an expert in LLM!
